# %% [markdown]
# <a href="https://colab.research.google.com/github/mahathirumalathi97-web/Cross-Market-Analysis/blob/main/Cross_Analysis_Market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                                            CROSS MARKET ANALYSIS

# %% [markdown]
# # 1. Crypto Currency Coins

# %%
url:"https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&page=1&sparkline=False"

# %%
import requests
records=[]
for i in range(1,6):
     url=f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&page={i}&sparkline=False"
     response=requests.get(url)
     if response.status_code==200:
         data=response.json()
         records.extend(data)

# %%
import pandas as pd
df=pd.DataFrame(records)

# %%
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...     6028069.00
# 1  https://coin-images.coingecko.com/coins/images...      176739.00
# 2  https://coin-images.coingecko.com/coins/images...          90.08
# 3  https://coin-images.coingecko.com/coins/images...       59375.00
# 4  https://coin-images.coingecko.com/coins/images...         114.47
#
#         market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  120313078241861                1             1.203131e+14  1.039036e+13
# 1   21317733606195                2             2.131773e+13  5.172751e+12
# 2   16729719569747                3             1.722219e+13  1.626731e+13
# 3    8093370004395                4             8.093370e+12  3.265292e+11
# 4    6956576556214                5             1.141807e+13  7.996038e+11
#
#      high_24h  ...  total_supply    max_supply          ath  \
# 0  6678579.00  ...  1.998482e+07  2.100000e+07  11187013.00
# 1   196845.00  ...  1.206935e+08           NaN    431946.00
# 2       90.34  ...  1.911830e+11           NaN       105.52
# 3    64948.00  ...  1.363598e+08  2.000000e+08    121422.00
# 4      140.14  ...  9.998572e+10  1.000000e+11       313.99
#
#    ath_change_percentage                  ath_date          atl  \
# 0              -46.11547  2025-10-06T18:57:42.558Z  3993.420000
# 1              -59.08309  2025-08-24T19:21:03.333Z    28.130000
# 2              -14.63665  2025-01-25T16:51:57.989Z    36.860000
# 3              -51.10058  2025-10-13T08:41:24.131Z     2.580000
# 4              -63.54264  2025-07-21T15:02:00.541Z     0.159343
#
#    atl_change_percentage                  atl_date  \
# 0           1.508501e+05  2013-07-05T00:00:00.000Z
# 1           6.281652e+05  2015-10-20T00:00:00.000Z
# 2           1.443715e+02  2015-03-02T00:00:00.000Z
# 3           2.297025e+06  2017-10-19T00:00:00.000Z
# 4           7.173963e+04  2013-08-16T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-02-05T17:37:45.079Z
# 1  {'times': 38.221080536598656, 'currency': 'btc...  2026-02-05T17:37:45.499Z
# 2                                               None  2026-02-05T17:37:46.571Z
# 3                                               None  2026-02-05T17:37:44.975Z
# 4                                               None  2026-02-05T17:37:53.760Z
#
# [5 rows x 26 columns]

# %%
import pandas as pd

df = pd.DataFrame(records)

df['last_updated'] = pd.to_datetime(df['last_updated'])

df['date'] = df['last_updated'].dt.date

df = df.drop('last_updated', axis=1)

df = df[['id', 'symbol', 'name', 'current_price', 'market_cap', 'market_cap_rank', 'total_volume', 'circulating_supply', 'total_supply', 'ath', 'atl', 'date']]

# %%
df.head()
# Out:
#             id symbol      name  current_price       market_cap  \
# 0      bitcoin    btc   Bitcoin     6028069.00  120313078241861
# 1     ethereum    eth  Ethereum      176739.00   21317733606195
# 2       tether   usdt    Tether          90.08   16729719569747
# 3  binancecoin    bnb       BNB       59375.00    8093370004395
# 4       ripple    xrp       XRP         114.47    6956576556214
#
#    market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                1  1.039036e+13        1.998482e+07  1.998482e+07
# 1                2  5.172751e+12        1.206935e+08  1.206935e+08
# 2                3  1.626731e+13        1.857160e+11  1.911830e+11
# 3                4  3.265292e+11        1.363598e+08  1.363598e+08
# 4                5  7.996038e+11        6.091732e+10  9.998572e+10
#
#            ath          atl        date
# 0  11187013.00  3993.420000  2026-02-05
# 1    431946.00    28.130000  2026-02-05
# 2       105.52    36.860000  2026-02-05
# 3    121422.00     2.580000  2026-02-05
# 4       313.99     0.159343  2026-02-05

# %%
df.to_csv("crypto_market_data.csv",index=False)

# %% [markdown]
# # 2. Top 3 Coins - Historical prices

# %%
url="https://api.coingecko.com/api/v3/coins/{'coins_id'}/market_chart?vs_currency=inr&days=365"

# %%
import requests
records=[]
url=f"https://api.coingecko.com/api/v3/coins/{'coins_id'}/market_chart?vs_currency=inr&days=365"
response=requests.get(url)
response
# Out:
# <Response [404]>

# %%
import requests
records=[]
url=f"https://api.coingecko.com/api/v3/coins/{'coins_id'}/market_chart?vs_currency=inr&days=365"
response=requests.get(url)
data=response.json()
records.extend(data)

# %%
import pandas as pd
df=pd.DataFrame(records)

# %%
import requests
import pandas as pd

url = f"https://api.coingecko.com/api/v3/coins/markets"

params = {
    "vs_currency": "inr",
    "order": "market_cap_desc",
    "per_page": 250,
    "page": 1,
    "sparkline": False
}

response = requests.get(url, params=params)
data = response.json()

df = pd.DataFrame(data)
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...     6434783.00
# 1  https://coin-images.coingecko.com/coins/images...      191021.00
# 2  https://coin-images.coingecko.com/coins/images...          90.29
# 3  https://coin-images.coingecko.com/coins/images...       62860.00
# 4  https://coin-images.coingecko.com/coins/images...         131.38
#
#         market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  128584302838326                1          128584302838326  7.577429e+12
# 1   23069066661450                2           23069066661450  4.439686e+12
# 2   16768141431673                3           17261746479975  1.270033e+13
# 3    8572577904759                4            8572577904759  2.663896e+11
# 4    8001732889605                5           13133524154681  4.821708e+11
#
#      high_24h  ...  total_supply    max_supply          ath  \
# 0  6929560.00  ...  1.998456e+07  2.100000e+07  11187013.00
# 1   206736.00  ...  1.206935e+08           NaN    431946.00
# 2       90.40  ...  1.911830e+11           NaN       105.52
# 3    69080.00  ...  1.363598e+08  2.000000e+08    121422.00
# 4      145.17  ...  9.998572e+10  1.000000e+11       313.99
#
#    ath_change_percentage                  ath_date          atl  \
# 0              -42.47988  2025-10-06T18:57:42.558Z  3993.420000
# 1              -55.77665  2025-08-24T19:21:03.333Z    28.130000
# 2              -14.43050  2025-01-25T16:51:57.989Z    36.860000
# 3              -48.23039  2025-10-13T08:41:24.131Z     2.580000
# 4              -58.15732  2025-07-21T15:02:00.541Z     0.159343
#
#    atl_change_percentage                  atl_date  \
# 0           1.610347e+05  2013-07-05T00:00:00.000Z
# 1           6.789345e+05  2015-10-20T00:00:00.000Z
# 2           1.449616e+02  2015-03-02T00:00:00.000Z
# 3           2.431856e+06  2017-10-19T00:00:00.000Z
# 4           8.235147e+04  2013-08-16T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-02-05T04:53:31.987Z
# 1  {'times': 38.66355698430938, 'currency': 'btc'...  2026-02-05T04:53:32.055Z
# 2                                               None  2026-02-05T04:53:30.206Z
# 3                                               None  2026-02-05T04:53:31.785Z
# 4                                               None  2026-02-05T04:53:29.889Z
#
# [5 rows x 26 columns]

# %%
import requests
from datetime import datetime
import pandas as pd

top_3 = df[df["market_cap_rank"] <= 3]
print(top_3[["id", "market_cap_rank", "current_price"]])
all_data = []

for coin_id in top_3["id"]:
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart"
    hist_params = {
         'vs_currency': 'inr',
         'days': 365
    }

    hist_data = requests.get(url, params=hist_params).json()

    if "prices" in hist_data:
        for price in hist_data["prices"]:
            timestamp = price[0]
            price_inr = price[1]

            date = datetime.fromtimestamp(timestamp / 1000).strftime("%Y-%m-%d")

            all_data.append({
                "coin_id": coin_id,
                "date": date,
                "price_inr": price_inr
            })
# Out:
#          id  market_cap_rank  current_price
# 0   bitcoin                1     6434783.00
# 1  ethereum                2      191021.00
# 2    tether                3          90.29

# %%
price_df = pd.DataFrame(all_data)
price_df.head()
# Out:
#    coin_id        date     price_inr
# 0  bitcoin  2025-02-06  8.435197e+06
# 1  bitcoin  2025-02-07  8.465026e+06
# 2  bitcoin  2025-02-08  8.476794e+06
# 3  bitcoin  2025-02-09  8.476775e+06
# 4  bitcoin  2025-02-10  8.468156e+06

# %%
display(df)
# Out:
#                         id  symbol          name  \
# 0                  bitcoin     btc       Bitcoin
# 1                 ethereum     eth      Ethereum
# 2                   tether    usdt        Tether
# 3              binancecoin     bnb           BNB
# 4                   ripple     xrp           XRP
# ..                     ...     ...           ...
# 245          bitmart-token     bmx       BitMart
# 246  jito-governance-token     jto          Jito
# 247           cheems-token  cheems  Cheems Token
# 248               wormhole       w      Wormhole
# 249          oasis-network    rose         Oasis
#
#                                                  image  current_price  \
# 0    https://coin-images.coingecko.com/coins/images...   6.898808e+06
# 1    https://coin-images.coingecko.com/coins/images...   2.052900e+05
# 2    https://coin-images.coingecko.com/coins/images...   9.016000e+01
# 3    https://coin-images.coingecko.com/coins/images...   6.865800e+04
# 4    https://coin-images.coingecko.com/coins/images...   1.450200e+02
# ..                                                 ...            ...
# 245  https://coin-images.coingecko.com/coins/images...   3.456000e+01
# 246  https://coin-images.coingecko.com/coins/images...   2.692000e+01
# 247  https://coin-images.coingecko.com/coins/images...   5.696000e-05
# 248  https://coin-images.coingecko.com/coins/images...   2.160000e+00
# 249  https://coin-images.coingecko.com/coins/images...   1.520000e+00
#
#           market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0    137978920238039                1          137978920238039  6.846886e+12
# 1     24799463069690                2           24799463069690  4.320123e+12
# 2     16744465749861                3           17237368399087  1.165692e+13
# 3      9368136157806                4            9368136157806  1.793705e+11
# 4      8829162026090                5           14506873544306  3.716577e+11
# ..               ...              ...                      ...           ...
# 245      11729363137              248              22096729729  5.448806e+08
# 246      11652925846              249              26924439590  1.830839e+09
# 247      11601560373              250              11601560373  1.239267e+08
# 248      11551970033              251              21680284865  2.274897e+09
# 249      11398569313              252              15176802999  2.320287e+09
#
#          high_24h  ...  total_supply    max_supply           ath  \
# 0    7.090583e+06  ...  1.998266e+07  2.100000e+07  1.118701e+07
# 1    2.102150e+05  ...  1.206936e+08           NaN  4.319460e+05
# 2    9.040000e+01  ...  1.911850e+11           NaN  1.055200e+02
# 3    7.023000e+04  ...  1.363598e+08  2.000000e+08  1.214220e+05
# 4    1.468700e+02  ...  9.998572e+10  1.000000e+11  3.139900e+02
# ..            ...  ...           ...           ...           ...
# 245  3.525000e+01  ...  6.394120e+08  8.816793e+08  5.271000e+01
# 246  2.750000e+01  ...  1.000000e+09           NaN  5.011900e+02
# 247  5.897000e-05  ...  2.036730e+14  2.197761e+14  1.851700e-04
# 248  2.260000e+00  ...  1.000000e+10  1.000000e+10  1.383700e+02
# 249  1.630000e+00  ...  1.000000e+10  1.000000e+10  4.430000e+01
#
#      ath_change_percentage                  ath_date           atl  \
# 0                -38.33199  2025-10-06T18:57:42.558Z  3.993420e+03
# 1                -52.47308  2025-08-24T19:21:03.333Z  2.813000e+01
# 2                -14.54278  2025-01-25T16:51:57.989Z  3.686000e+01
# 3                -43.45498  2025-10-13T08:41:24.131Z  2.580000e+00
# 4                -53.81332  2025-07-21T15:02:00.541Z  1.593430e-01
# ..                     ...                       ...           ...
# 245              -34.44496  2025-10-28T16:58:27.513Z  5.015230e-01
# 246              -94.62852  2023-12-07T16:04:48.717Z  2.488000e+01
# 247              -69.23713  2025-03-25T13:56:11.560Z  4.736520e-07
# 248              -98.43550  2024-04-03T11:46:35.308Z  2.000000e+00
# 249              -96.57543  2022-01-15T03:31:11.062Z  8.862670e-01
#
#      atl_change_percentage                  atl_date  \
# 0             1.726544e+05  2013-07-05T00:00:00.000Z
# 1             7.296596e+05  2015-10-20T00:00:00.000Z
# 2             1.446402e+02  2015-03-02T00:00:00.000Z
# 3             2.656189e+06  2017-10-19T00:00:00.000Z
# 4             9.091138e+04  2013-08-16T00:00:00.000Z
# ..                     ...                       ...
# 245           6.789931e+03  2020-03-13T02:12:53.990Z
# 246           8.183440e+00  2026-02-02T03:45:11.561Z
# 247           1.192644e+04  2023-09-04T18:45:23.807Z
# 248           8.023200e+00  2026-01-31T18:45:14.131Z
# 249           7.116516e+01  2025-12-21T17:40:51.914Z
#
#                                                    roi  \
# 0                                                 None
# 1    {'times': 38.7706354584933, 'currency': 'btc',...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 245                                               None
# 246                                               None
# 247                                               None
# 248                                               None
# 249                                               None
#
#                  last_updated
# 0    2026-02-04T09:04:21.510Z
# 1    2026-02-04T09:04:21.652Z
# 2    2026-02-04T09:04:07.974Z
# 3    2026-02-04T09:04:21.556Z
# 4    2026-02-04T09:04:15.007Z
# ..                        ...
# 245  2026-02-04T09:04:10.570Z
# 246  2026-02-04T09:04:16.686Z
# 247  2026-02-04T09:04:11.038Z
# 248  2026-02-04T09:04:25.274Z
# 249  2026-02-04T09:04:20.729Z
#
# [250 rows x 26 columns]

# %%
import pandas as pd
price_df = pd.DataFrame(all_data)
price_df.to_csv("top3_daily_price_1year_inr.csv",index=False)

# %% [markdown]
# Oil prices (WTI Crude)

# %% [markdown]
# # 3. Oil Prices (WTI Crude)

# %%
url='https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv'

# %%
import pandas as pd
oil_df=pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")
oil_df
# Out:
#              Date  Price
# 0      1986-01-02  25.56
# 1      1986-01-03  26.00
# 2      1986-01-06  26.53
# 3      1986-01-07  25.85
# 4      1986-01-08  25.87
# ...           ...    ...
# 10085  2026-01-27  62.04
# 10086  2026-01-28  62.75
# 10087  2026-01-29  64.77
# 10088  2026-01-30  64.50
# 10089  2026-02-02  61.60
#
# [10090 rows x 2 columns]

# %%
import pandas as pd
from datetime import datetime

start_date_str = '2020-01-01'
end_date_str = '2026-01-31'

start_date = pd.to_datetime(start_date_str)
end_date = pd.to_datetime(end_date_str)

oil_df['Date'] = pd.to_datetime(oil_df['Date'])

filtered_oil_df = oil_df[(oil_df['Date'] >= start_date) & (oil_df['Date'] <= end_date)]
filtered_oil_df
# Out:
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10084 2026-01-26  60.46
# 10085 2026-01-27  62.04
# 10086 2026-01-28  62.75
# 10087 2026-01-29  64.77
# 10088 2026-01-30  64.50
#
# [1520 rows x 2 columns]

# %%
filtered_oil_df.to_csv('oil_df.csv',index=False)

# %% [markdown]
# # 4.Stock Prices (Yahoo Finance API)

# %%
import yfinance as yf
import pandas as pd

# Choose indices
tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-01-12"

# Download historical data
stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
stocks_df.head()
# Out:
# /tmp/ipython-input-1369541528.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
# [*********************100%***********************]  3 of 3 completed
# Ticker             ^NSEI                                                      \
# Price               Open          High           Low         Close    Volume
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000  304100.0
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195  407700.0
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391  428800.0
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805  396500.0
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195  447800.0
#
# Ticker            ^IXIC                                                       \
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  9039.459961  9093.429688  9010.889648  9092.190430  2.862700e+09
# 2020-01-03  8976.429688  9065.759766  8976.429688  9020.769531  2.586520e+09
# 2020-01-06  8943.500000  9072.410156  8943.500000  9071.469727  2.810450e+09
# 2020-01-07  9076.639648  9091.929688  9042.549805  9068.580078  2.381740e+09
#
# Ticker            ^GSPC
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3.459930e+09
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3.484700e+09
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3.702460e+09
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3.435910e+09

# %%
import pandas as pd
df=stocks_df['^IXIC'].reset_index()
df.columns=pd.MultiIndex.from_product([['^IXIC'],list(df.columns)])

display(df)
# Out:
#           ^IXIC                                                          \
#            Date          Open          High           Low         Close
# 0    2020-01-01           NaN           NaN           NaN           NaN
# 1    2020-01-02   9039.459961   9093.429688   9010.889648   9092.190430
# 2    2020-01-03   8976.429688   9065.759766   8976.429688   9020.769531
# 3    2020-01-06   8943.500000   9072.410156   8943.500000   9071.469727
# 4    2020-01-07   9076.639648   9091.929688   9042.549805   9068.580078
# ...         ...           ...           ...           ...           ...
# 1558 2026-01-05  23449.669922  23476.509766  23332.230469  23395.820312
# 1559 2026-01-06  23446.960938  23559.150391  23389.570312  23547.169922
# 1560 2026-01-07  23544.890625  23723.369141  23504.210938  23584.279297
# 1561 2026-01-08  23548.880859  23558.169922  23353.460938  23480.019531
# 1562 2026-01-09  23496.210938  23721.150391  23426.480469  23671.349609
#
#
#             Volume
# 0              NaN
# 1     2.862700e+09
# 2     2.586520e+09
# 3     2.810450e+09
# 4     2.381740e+09
# ...            ...
# 1558  8.737320e+09
# 1559  9.012640e+09
# 1560  8.396920e+09
# 1561  7.723140e+09
# 1562  8.124420e+09
#
# [1563 rows x 6 columns]

# %%
stocks_df['^IXIC'].reset_index().to_csv('IXIC.csv',index=False)

# %%
import pandas as pd
df=stocks_df["^GSPC"].reset_index()
df.columns=pd.MultiIndex.from_product([["^GSPC"],list(df.columns)])

display(df)
# Out:
#           ^GSPC                                                      \
#            Date         Open         High          Low        Close
# 0    2020-01-01          NaN          NaN          NaN          NaN
# 1    2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 2    2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 3    2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 4    2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# ...         ...          ...          ...          ...          ...
# 1558 2026-01-05  6892.189941  6920.379883  6891.560059  6902.049805
# 1559 2026-01-06  6908.029785  6948.689941  6904.020020  6944.819824
# 1560 2026-01-07  6945.069824  6965.689941  6919.189941  6920.930176
# 1561 2026-01-08  6914.109863  6931.279785  6899.330078  6921.459961
# 1562 2026-01-09  6927.830078  6978.359863  6917.640137  6966.279785
#
#
#             Volume
# 0              NaN
# 1     3.459930e+09
# 2     3.484700e+09
# 3     3.702460e+09
# 4     3.435910e+09
# ...            ...
# 1558  5.771930e+09
# 1559  5.509680e+09
# 1560  5.214480e+09
# 1561  5.333200e+09
# 1562  5.163900e+09
#
# [1563 rows x 6 columns]

# %%
stocks_df["^GSPC"].reset_index().to_csv('GSPC.csv',index=False)

# %%
import pandas as pd
df=stocks_df["^NSEI"].reset_index()
df.columns=pd.MultiIndex.from_product([["^NSEI"],list(df.columns)])

display(df)
# Out:
#           ^NSEI                                                          \
#            Date          Open          High           Low         Close
# 0    2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 1    2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2    2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391
# 3    2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805
# 4    2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195
# ...         ...           ...           ...           ...           ...
# 1558 2026-01-05  26333.699219  26373.199219  26210.050781  26250.300781
# 1559 2026-01-06  26189.699219  26273.949219  26124.750000  26178.699219
# 1560 2026-01-07  26143.099609  26187.150391  26067.900391  26140.750000
# 1561 2026-01-08  26106.500000  26133.199219  25858.449219  25876.849609
# 1562 2026-01-09  25840.400391  25940.599609  25623.000000  25683.300781
#
#
#         Volume
# 0     304100.0
# 1     407700.0
# 2     428800.0
# 3     396500.0
# 4     447800.0
# ...        ...
# 1558  338800.0
# 1559  383000.0
# 1560  338200.0
# 1561  328500.0
# 1562  348800.0
#
# [1563 rows x 6 columns]

# %%
stocks_df["^NSEI"].reset_index().to_csv('NSEI.csv',index=False)

# %%
import pandas as pd
import glob
import os

# %%
df_list = ['IXIC.csv','GSPC.csv','NSEI.csv']

# %%
df_list = []

for file in df_list:
    df = pd.read_csv(file)
    df_list.append(df)

# %%
import pandas as pd

filenames_to_load = ['IXIC.csv','GSPC.csv','NSEI.csv']

dataframes_to_concat = []

for file_name in filenames_to_load:
    df_temp = pd.read_csv(file_name)
    dataframes_to_concat.append(df_temp)

combined_df = pd.concat(dataframes_to_concat, ignore_index=True)

# %%
import pandas as pd
import yfinance as yf

all_stocks_data = []

for ticker_symbol in tickers:

    temp_df = stocks_df[ticker_symbol].copy()
    temp_df = temp_df.reset_index()

    temp_df.columns = [col.lower() for col in temp_df.columns]

    temp_df['ticker'] = ticker_symbol

    if 'adj close' in temp_df.columns:
        temp_df = temp_df.drop(columns=['adj close'])

    all_stocks_data.append(temp_df)

df_final_stocks = pd.concat(all_stocks_data, ignore_index=True)

sql_columns = ['date', 'open', 'high', 'low', 'close', 'volume', 'ticker']
df_final_stocks = df_final_stocks[sql_columns]

display(df_final_stocks.head())

df = df_final_stocks
# Out:
#         date         open         high          low        close  \
# 0 2020-01-01          NaN          NaN          NaN          NaN
# 1 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 2 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 3 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 4 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
#
#          volume ticker
# 0           NaN  ^GSPC
# 1  3.459930e+09  ^GSPC
# 2  3.484700e+09  ^GSPC
# 3  3.702460e+09  ^GSPC
# 4  3.435910e+09  ^GSPC

# %%
combined_df.to_csv("combined_file.csv", index=False)

# %% [markdown]
# # Connect to DataFrame into SQL

# %%
import sqlite3

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('Market.db')
print("Connected to in-memory database")
# Out:
# Connected to in-memory database

# %%
import pandas as pd
df=pd.read_csv("crypto_market_data.csv")

# %% [markdown]
# # 1.Cryptocurrencies Table created

# %%
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS Cryptocurrencies (
       id VARCHAR(50) PRIMARY KEY, ---- Unique ID from CoinGecko (e.g., “bitcoin”)
       symbol VARCHAR(50), ---Short symbol (e.g., BTC, ETH)
       name  VARCHAR(100), ---Full name of the cryptocurrency
       current_price DECIMAL(18, 6), --Current trading price INR
       market_cap BIGINT, ----Market capitalization (INR)
       market_cap_rank INT, ---Rank by market capitalization
       total_volume BIGINT, ---Trading volume (24h, INR)
       circulating_supply DECIMAL(20, 6), ---Coins in circulation
       total_supply DECIMAL(20, 6), ---Total supply (if available)
       ath DECIMAL(18, 6), ----All-time high price (INR)
       atl DECIMAL(18, 6),---All-time low price (INR)
       date_only DATE ----Last updated
    )
''')

# %% [markdown]
# # Insert into Table

# %%
insert_query = """INSERT OR IGNORE INTO Cryptocurrencies(id, symbol, name, current_price, market_cap,
       market_cap_rank, total_volume, circulating_supply, total_supply,
       ath, atl, date) VALUES (?,?,?,?,?,?,?,?,?,?,?,?)"""

for i, row in df.iterrows():
    values = (row['id'],row['symbol'],row['name'],row['current_price'],row['market_cap'],row['market_cap_rank'],
              row['total_volume'],row['circulating_supply'],row['total_supply'],row['ath'],row['atl'],row['date'])
    cursor.execute(insert_query,values)
conn.commit()

# %% [markdown]
# # Insert After Viewing Values

# %%
import pandas as pd

cursor.execute("select * from Cryptocurrencies")
rows = cursor.fetchall()
columns = [i[0] for i in cursor.description]
df = pd.DataFrame(rows,columns=columns)
df.head()
# Out:
#             id symbol      name  current_price       market_cap  \
# 0      bitcoin    btc   Bitcoin     6904934.00  137837336354242
# 1     ethereum    eth  Ethereum      205475.00   24798076729821
# 2       tether   usdt    Tether          90.16   16746403768606
# 3  binancecoin    bnb       BNB       68702.00    9365169624314
# 4       ripple    xrp       XRP         145.09    8832873033687
#
#    market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                1  6.805965e+12        1.998266e+07  1.998266e+07
# 1                2  4.329191e+12        1.206936e+08  1.206936e+08
# 2                3  1.165725e+13        1.857181e+11  1.911850e+11
# 3                4  1.790752e+11        1.363598e+08  1.363598e+08
# 4                5  3.718763e+11        6.085323e+10  9.998572e+10
#
#            ath          atl        date
# 0  11187013.00  3993.420000  2026-02-04
# 1    431946.00    28.130000  2026-02-04
# 2       105.52    36.860000  2026-02-04
# 3    121422.00     2.580000  2026-02-04
# 4       313.99     0.159343  2026-02-04

# %%
df.isnull().sum()
# Out:
# id                    0
# symbol                0
# name                  0
# current_price         0
# market_cap            0
# market_cap_rank       0
# total_volume          0
# circulating_supply    0
# total_supply          0
# ath                   0
# atl                   0
# date                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.read_sql(
    "SELECT count(*) as total_rows FROM Cryptocurrencies ",
    conn
)
# Out:
#    total_rows
# 0         763

# %% [markdown]
# # 2. Crypto_prices Table Created

# %%
cursor.execute('''
    CREATE TABLE top3_daily_price_1year_inr(
      coin_id TEXT VARCHAR(50),-----  FOREIGN KEY (coin_id) REFERENCES Cryptocurrencies (id)
      date DATE,
      price_inr DECIMAL(18, 6)

   )
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-3680777033.py in <cell line: 0>()
# ----> 1 cursor.execute('''
#       2     CREATE TABLE top3_daily_price_1year_inr(
#       3       coin_id TEXT VARCHAR(50),-----  FOREIGN KEY (coin_id) REFERENCES Cryptocurrencies (id)
#       4       date DATE,
#       5       price_inr DECIMAL(18, 6)
#
# OperationalError: table top3_daily_price_1year_inr already exists

# %% [markdown]
# # Insert into Table

# %%
insert_query = """INSERT INTO top3_daily_price_1year_inr (coin_id ,date,price_inr) VALUES (?,?,?)"""

for i, row in df.iterrows():
    values = (row['coin_id'],row['date'],row['price_inr'])
    cursor.execute(insert_query,values)
conn.commit()

# %%
df.isnull().sum()
# Out:
# coin_id      0
# date         0
# price_inr    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.read_sql(
    "SELECT count(*)as total_rows FROM top3_daily_price_1year_inr ", conn)
# Out:
#    total_rows
# 0        1098

# %% [markdown]
# # Insert After Viewing Values

# %%
import pandas as pd

cursor.execute("select * from top3_daily_price_1year_inr")
rows = cursor.fetchall()
columns = [i[0] for i in cursor.description]
df = pd.DataFrame(rows,columns=columns)
df.head()
# Out:
#    coin_id        date     price_inr
# 0  bitcoin  2025-02-05  8.544188e+06
# 1  bitcoin  2025-02-06  8.435197e+06
# 2  bitcoin  2025-02-07  8.465026e+06
# 3  bitcoin  2025-02-08  8.476794e+06
# 4  bitcoin  2025-02-09  8.476775e+06

# %% [markdown]
# 3.OIL _ PRICES

# %%
import pandas as pd
df=pd.read_csv("/content/oil_df.csv")
df.head()
# Out:
#          Date  Price
# 0  2020-01-02  61.17
# 1  2020-01-03  63.00
# 2  2020-01-06  63.27
# 3  2020-01-07  62.70
# 4  2020-01-08  59.65

# %% [markdown]
# # 3. Oil_Prices Table Created

# %%
cursor.execute('''
    CREATE TABLE oil_prices(
       date DATE PRIMARY KEY,
      price_inr DECIMAL(18, 6) -- WTI crude oil price per barrel (INR)
   )
''')

conn.commit()

# %% [markdown]
# # Insert into Table

# %%
insert_query = """INSERT or ignore INTO oil_prices (date,price_inr) VALUES (?,?)"""

for i, row in df.iterrows():
    values = (row['Date'],row['Price'])
    cursor.execute(insert_query,values)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4017334305.py in <cell line: 0>()
#       2
#       3 for i, row in df.iterrows():
# ----> 4     values = (row['Date'],row['Price'])
#       5     cursor.execute(insert_query,values)
#       6 conn.commit()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
df.isnull().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# # Insert After Viewing Values

# %%
import pandas as pd
cursor.execute("select * from oil_prices")
rows = cursor.fetchall()
columns = [i[0] for i in cursor.description]
df = pd.DataFrame(rows,columns=columns)
df.head()
# Out:
#          date  price_inr
# 0  2020-01-02      61.17
# 1  2020-01-03      63.00
# 2  2020-01-06      63.27
# 3  2020-01-07      62.70
# 4  2020-01-08      59.65

# %% [markdown]
# # 4. Stock _ Prices Table Created

# %%
df.to_csv("stock_prices.csv",index=False)

# %%
import pandas as pd
df=pd.read_csv("/content/stock_prices.csv")
df.head()
# Out:
#             id symbol      name  current_price       market_cap  \
# 0      bitcoin    btc   Bitcoin     6028069.00  120313078241861
# 1     ethereum    eth  Ethereum      176739.00   21317733606195
# 2       tether   usdt    Tether          90.08   16729719569747
# 3  binancecoin    bnb       BNB       59375.00    8093370004395
# 4       ripple    xrp       XRP         114.47    6956576556214
#
#    market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                1  1.039036e+13        1.998482e+07  1.998482e+07
# 1                2  5.172751e+12        1.206935e+08  1.206935e+08
# 2                3  1.626731e+13        1.857160e+11  1.911830e+11
# 3                4  3.265292e+11        1.363598e+08  1.363598e+08
# 4                5  7.996038e+11        6.091732e+10  9.998572e+10
#
#            ath          atl        date
# 0  11187013.00  3993.420000  2026-02-05
# 1    431946.00    28.130000  2026-02-05
# 2       105.52    36.860000  2026-02-05
# 3    121422.00     2.580000  2026-02-05
# 4       313.99     0.159343  2026-02-05

# %%
df.isnull().sum()
# Out:
# date         0
# price_inr    0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# %%
df.dropna(inplace=True)

# %%
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE stock_prices(
      date DATE,---Trading date
      open decimal(18,6),-----Opening price
      high decimal(18,6),----Highest price of the day
      low decimal(18,6),----Lowest price of the day
      close decimal,----Closing price
      volume bigint,----Trading volume
      ticker varchar(20)---Stock index symbol (e.g., ^GSPC, ^IXIC)


   )
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-3971321722.py in <cell line: 0>()
#       1 cursor = conn.cursor()
#       2
# ----> 3 cursor.execute('''
#       4     CREATE TABLE stock_prices(
#       5       date DATE,---Trading date
#
# OperationalError: table stock_prices already exists

# %% [markdown]
# # Insert into Table

# %%
df = df_final_stocks

df.dropna(inplace=True)

df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

insert_query = """INSERT or ignore INTO stock_prices (date,open,high,low,close,volume,ticker) VALUES (?,?,?,?,?,?,?)"""

for i, row in df.iterrows():
    values = (row['date'],row['open'],row['high'],row['low'],row['close'],row['volume'],row['ticker'])
    cursor.execute(insert_query,values)
conn.commit()

# %% [markdown]
# # Insert After Viewing Values

# %%
import pandas as pd
cursor.execute("select * from stock_prices")
rows = cursor.fetchall()
columns = [i[0] for i in cursor.description]
df = pd.DataFrame(rows,columns=columns)
df.head()
# Out:
#          date         open         high          low        close      volume  \
# 0  2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3459930000
# 1  2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3484700000
# 2  2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3702460000
# 3  2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3435910000
# 4  2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3726840000
#
#   ticker
# 0  ^GSPC
# 1  ^GSPC
# 2  ^GSPC
# 3  ^GSPC
# 4  ^GSPC

# %%
df['ticker'].value_counts()
# Out:
# ticker
# ^GSPC    1514
# ^IXIC    1514
# ^NSEI    1493
# Name: count, dtype: int64

# %%
df.to_csv("stock_prices.csv",index=False)

# %% [markdown]
# # SQL Queries

# %% [markdown]
# # Cryptocurrencies - (1 to 5)

# %% [markdown]
# # 1.Find the highest oil price in the last 5 years.

# %%
import pandas as pd
pd.read_sql("""SELECT name, market_cap
    FROM Cryptocurrencies
    ORDER BY market_cap DESC
    LIMIT 3;""", conn)
# Out:
#        name       market_cap
# 0   Bitcoin  137837336354242
# 1  Ethereum   24798076729821
# 2    Tether   16746403768606

# %% [markdown]
# # 2.Get the average oil price per year.

# %%
pd.read_sql("""SELECT
   id,symbol,name,circulating_supply,total_supply,
   ROUND((circulating_supply * 100.0) / total_supply, 2) AS supply_percentage
   FROM Cryptocurrencies
   WHERE total_supply IS NOT NULL
   AND total_supply > 0
   AND circulating_supply >= 0.9 * total_supply
   ORDER BY supply_percentage DESC;
   """,conn)
# Out:
#                 id symbol         name  circulating_supply  total_supply  \
# 0      standx-dusd   dusd  StandX DUSD        1.319540e+08  1.318535e+08
# 1          bitcoin    btc      Bitcoin        1.998266e+07  1.998266e+07
# 2         ethereum    eth     Ethereum        1.206936e+08  1.206936e+08
# 3      binancecoin    bnb          BNB        1.363598e+08  1.363598e+08
# 4         usd-coin   usdc         USDC        7.082520e+10  7.082532e+10
# ..             ...    ...          ...                 ...           ...
# 416         axelar    axl       Axelar        1.114596e+09  1.230540e+09
# 417         proton    xpr  XPR Network        2.842404e+10  3.141241e+10
# 418        cartesi   ctsi      Cartesi        9.030541e+08  1.000000e+09
# 419        siacoin     sc      Siacoin        5.602564e+10  6.221753e+10
# 420  conflux-token    cfx      Conflux        5.159697e+09  5.732659e+09
#
#      supply_percentage
# 0               100.08
# 1               100.00
# 2               100.00
# 3               100.00
# 4               100.00
# ..                 ...
# 416              90.58
# 417              90.49
# 418              90.31
# 419              90.05
# 420              90.01
#
# [421 rows x 6 columns]

# %% [markdown]
# # 3.Show oil prices during COVID crash (March–April 2020).

# %%
pd.read_sql("""SELECT
    id,symbol,name,current_price,ath,
    ROUND((current_price / ath) * 100, 2) AS percent_of_ath
    FROM Cryptocurrencies
    WHERE ath IS NOT NULL
    AND ath > 0
    AND current_price >= 0.9 * ath
    ORDER BY percent_of_ath DESC;
    """, conn)
# Out:
#                                         id   symbol  \
# 0                                     tria     tria
# 1                                   usda-2     usda
# 2                                    glidr    glidr
# 3                               aintivirus    ainti
# 4                  fidelity-digital-dollar     fidd
# ..                                     ...      ...
# 96       securitize-tokenized-aaa-clo-fund     stac
# 97                           pleasing-gold    pgold
# 98   alphabet-class-a-ondo-tokenized-stock  googlon
# 99             sygnum-fiusd-liquidity-fund    fiusd
# 100    spdr-s-p-500-etf-ondo-tokenized-etf    spyon
#
#                                         name  current_price         ath  \
# 0                                       TRIA           2.09        2.06
# 1                                       USDa          90.53       90.58
# 2                                      Glidr         116.27      116.45
# 3                                 AIntivirus           2.86        2.89
# 4                    Fidelity Digital Dollar          90.38       91.43
# ..                                       ...            ...         ...
# 96         Securitize Tokenized AAA CLO Fund       90867.00    92829.00
# 97                             Pleasing Gold      456429.00   506532.00
# 98   Alphabet Class A (Ondo Tokenized Stock)       30854.00    31792.00
# 99               Sygnum FIUSD Liquidity Fund     1061690.00  1083341.00
# 100    SPDR S&P 500 ETF (Ondo Tokenized ETF)       62411.00    64397.00
#
#      percent_of_ath
# 0            101.46
# 1             99.94
# 2             99.85
# 3             98.96
# 4             98.85
# ..              ...
# 96             0.00
# 97             0.00
# 98             0.00
# 99             0.00
# 100            0.00
#
# [101 rows x 6 columns]

# %% [markdown]
# # 4.Find the lowest price of oil in the last 10 years.

# %%
pd.read_sql("""SELECT
ROUND(AVG(market_cap_rank), 2) AS avg_market_cap_rank
FROM Cryptocurrencies
WHERE total_volume >= 1000000000
AND market_cap_rank IS NOT NULL;
""", conn)
# Out:
#    avg_market_cap_rank
# 0               250.67

# %% [markdown]
# # 5.Calculate the volatility of oil prices (max-min difference per year).

# %%
pd.read_sql("""SELECT
id,symbol,name,date
FROM Cryptocurrencies
ORDER BY date DESC
LIMIT 5;
  """,conn    )
# Out:
#                                            id   symbol  \
# 0                     fidelity-digital-dollar     fidd
# 1  circle-internet-group-ondo-tokenized-stock   crclon
# 2                             orderly-network    order
# 3                              savings-crvusd  scrvusd
# 4                                   superwalk     grnd
#
#                                            name        date
# 0                       Fidelity Digital Dollar  2026-02-05
# 1  Circle Internet Group (Ondo Tokenized Stock)  2026-02-05
# 2                                       Orderly  2026-02-05
# 3                                Savings crvUSD  2026-02-05
# 4                                SuperWalk GRND  2026-02-05

# %% [markdown]
# # Crypto_prices (daily prices of top coins - (6 - 10)

# %% [markdown]
# # 6.Find the highest daily price of Bitcoin in the last 365 days.

# %%
pd.read_sql("""SELECT
coin_id, MAX(price_inr) AS highest_price_last_365_days
FROM top3_daily_price_1year_inr
WHERE coin_id = 'bitcoin'
AND date >= DATE('now', '-365 day');
""", conn)
# Out:
#    coin_id  highest_price_last_365_days
# 0  bitcoin                 1.107047e+07

# %% [markdown]
# # 7.Calculate the average daily price of Ethereum in the past 1 year.

# %%
pd.read_sql("""Select
  avg(price_inr)as avg_price_last_365_days
  from top3_daily_price_1year_inr
  where coin_id = 'ethereum'
  and date >= DATE('now', '-366 day');
  """,conn)
# Out:
#    avg_price_last_365_days
# 0            266752.678736

# %% [markdown]
# # 8.Show the daily price trend of Bitcoin in January 2025.

# %%
pd.read_sql("""Select
 date,coin_id,price_inr
 from top3_daily_price_1year_inr
 where coin_id = 'bitcoin'
 and date between '2025-01-01' and '2025-12-31'
 order by date;
 """,conn)
# Out:
#            date  coin_id     price_inr
# 0    2025-02-05  bitcoin  8.544188e+06
# 1    2025-02-06  bitcoin  8.435197e+06
# 2    2025-02-06  bitcoin  8.435197e+06
# 3    2025-02-07  bitcoin  8.465026e+06
# 4    2025-02-07  bitcoin  8.465026e+06
# ..          ...      ...           ...
# 654  2025-12-29  bitcoin  7.887771e+06
# 655  2025-12-30  bitcoin  7.835388e+06
# 656  2025-12-30  bitcoin  7.835388e+06
# 657  2025-12-31  bitcoin  7.936951e+06
# 658  2025-12-31  bitcoin  7.936951e+06
#
# [659 rows x 3 columns]

# %% [markdown]
# # 9.Find the coin with the highest average price over 1 year.

# %%
pd.read_sql("""Select
 coin_id, avg(price_inr)as avg_price
 from top3_daily_price_1year_inr
 group by coin_id
 order by avg_price desc
 limit 1;
 """,conn)
# Out:
#    coin_id     avg_price
# 0  bitcoin  8.803954e+06

# %% [markdown]
# # 10.Get the % change in Bitcoin’s price between Sep 2024 and Sep 2025.

# %%
pd.read_sql("""SELECT
  ((MAX(price_inr) - MIN(price_inr)) / MIN(price_inr)) * 100 AS pct_change
   FROM top3_daily_price_1year_inr
   WHERE coin_id='bitcoin'
   AND date BETWEEN '2025-01-27' AND '2026-01-26';
   """, conn)
# Out:
#    pct_change
# 0   67.798154

# %% [markdown]
# # Oil_prices (11 -15)

# %% [markdown]
# # 11.Find the highest oil price in the last 5 years.

# %%
pd.read_sql("""Select
  max(price_inr) as highest_price from oil_prices
  where date >= DATE('now', '-5 years');
  """,conn)
# Out:
#    highest_price
# 0         123.64

# %% [markdown]
# # 12.Get the average oil price per year.

# %%
pd.read_sql("""SELECT
  strftime('%Y', date) AS year,
  ROUND(AVG(price_inr), 2) AS avg_price
  FROM oil_prices
  GROUP BY year
  ORDER BY year;
  """,conn)
# Out:
#    year  avg_price
# 0  2020      39.16
# 1  2021      68.14
# 2  2022      94.90
# 3  2023      77.58
# 4  2024      76.63
# 5  2025      65.39
# 6  2026      59.17

# %% [markdown]
# # 13.Show oil prices during COVID crash (March–April 2020).

# %%
pd.read_sql("""SELECT
  date,price_inr
  FROM oil_prices
  WHERE date BETWEEN '2020-03-01' AND '2020-04-30'
  ORDER BY date;
  """,conn)
# Out:
#           date  price_inr
# 0   2020-03-02      46.78
# 1   2020-03-03      47.27
# 2   2020-03-04      46.78
# 3   2020-03-05      45.90
# 4   2020-03-06      41.14
# 5   2020-03-09      31.05
# 6   2020-03-10      34.47
# 7   2020-03-11      33.13
# 8   2020-03-12      31.56
# 9   2020-03-13      31.72
# 10  2020-03-16      28.96
# 11  2020-03-17      26.96
# 12  2020-03-18      20.48
# 13  2020-03-19      25.09
# 14  2020-03-20      19.48
# 15  2020-03-23      23.33
# 16  2020-03-24      21.03
# 17  2020-03-25      20.75
# 18  2020-03-26      16.60
# 19  2020-03-27      15.48
# 20  2020-03-30      14.10
# 21  2020-03-31      20.51
# 22  2020-04-01      20.28
# 23  2020-04-02      25.18
# 24  2020-04-03      28.36
# 25  2020-04-06      26.21
# 26  2020-04-07      23.54
# 27  2020-04-08      24.97
# 28  2020-04-09      22.90
# 29  2020-04-13      22.36
# 30  2020-04-14      20.15
# 31  2020-04-15      19.96
# 32  2020-04-16      19.82
# 33  2020-04-17      18.31
# 34  2020-04-20     -36.98
# 35  2020-04-21       8.91
# 36  2020-04-22      13.64
# 37  2020-04-23      15.06
# 38  2020-04-24      15.99
# 39  2020-04-27      12.17
# 40  2020-04-28      12.40
# 41  2020-04-29      15.04
# 42  2020-04-30      19.23

# %% [markdown]
# # 14.Find the lowest price of oil in the last 10 years.

# %%
pd.read_sql("""Select
   min(price_inr) as lowest_price from oil_prices
   where date >= DATE('now', '-10 years');
   """,conn)
# Out:
#    lowest_price
# 0        -36.98

# %% [markdown]
# # 15.Calculate the volatility of oil prices (max-min difference per year).

# %%
pd.read_sql("""SELECT
  strftime('%Y', date) AS year,
  MAX(price_inr) AS max_price,
  MIN(price_inr) AS min_price,
  ROUND(MAX(price_inr) - MIN(price_inr), 2) AS volatility
  FROM oil_prices
  GROUP BY year
  ORDER BY year;
  """,conn)
# Out:
#    year  max_price  min_price  volatility
# 0  2020      63.27     -36.98      100.25
# 1  2021      85.64      47.47       38.17
# 2  2022     123.64      71.05       52.59
# 3  2023      93.67      66.61       27.06
# 4  2024      87.69      66.73       20.96
# 5  2025      80.73      55.44       25.29
# 6  2026      61.84      56.01        5.83

# %% [markdown]
# # stock_prices - (16 - 20)

# %% [markdown]
# # 16.Get all stock prices for a given ticker

# %%
pd.read_sql("""
SELECT *
FROM stock_prices
GROUP BY ticker
ORDER BY date;
""",conn)
# Out:
#          date          open          high           low         close  \
# 0  2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 1  2020-01-02   3244.669922   3258.139893   3235.530029   3257.850098
# 2  2020-01-02   9039.459961   9093.429688   9010.889648   9092.190430
#
#        volume ticker
# 0      304100  ^NSEI
# 1  3459930000  ^GSPC
# 2  2862700000  ^IXIC

# %% [markdown]
# # 17.Find the highest closing price for NASDAQ (^IXIC)

# %%
pd.read_sql("""
SELECT MAX(close) AS highest_close
FROM stock_prices
WHERE ticker = '^IXIC';
""",conn)
# Out:
#    highest_close
# 0   23958.470703

# %% [markdown]
# # 18.List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)

# %%
pd.read_sql("""
SELECT date, (high - low) AS price_diff
FROM stock_prices
WHERE ticker = '^GSPC'
ORDER BY price_diff DESC
LIMIT 5;
""",conn)
# Out:
#          date  price_diff
# 0  2025-04-09  532.909668
# 1  2025-04-07  411.529785
# 2  2025-04-08  357.050293
# 3  2025-04-10  237.879883
# 4  2025-11-20  236.300293

# %% [markdown]
# # 19.Get monthly average closing price for each ticker

# %%
pd.read_sql("""
SELECT
  ticker,
  strftime('%Y-%m', date) AS month,
  AVG(close) AS avg_close
FROM stock_prices
GROUP BY ticker, month
ORDER BY ticker, month;
""",conn)
# Out:
#     ticker    month     avg_close
# 0    ^GSPC  2020-01   3278.202858
# 1    ^GSPC  2020-02   3277.314183
# 2    ^GSPC  2020-03   2652.393632
# 3    ^GSPC  2020-04   2761.975226
# 4    ^GSPC  2020-05   2919.608484
# ..     ...      ...           ...
# 214  ^NSEI  2025-09  24942.674982
# 215  ^NSEI  2025-10  25494.083519
# 216  ^NSEI  2025-11  25894.834396
# 217  ^NSEI  2025-12  25997.738725
# 218  ^NSEI  2026-01  26086.428850
#
# [219 rows x 3 columns]

# %% [markdown]
# # 20.Get average trading volume of NSEI in 2024

# %%
pd.read_sql("""
SELECT AVG(volume) AS avg_volume_2024
FROM stock_prices
WHERE ticker = '^NSEI'
  AND date BETWEEN '2024-01-01' AND '2024-12-31';
  """,conn)
# Out:
#    avg_volume_2024
# 0    313560.162602

# %% [markdown]
# # Based on 4 tables - (21 - 30)

# %% [markdown]
# # 21. Find the Average Bitcoin vs stock volume average price.

# %%
pd.read_sql("""Select
coin_id, avg(price_inr)as avg_price,
avg(s.volume) AS avg_stock_volume
from top3_daily_price_1year_inr t
join stock_prices s on t.date = s.date
where coin_id = 'bitcoin'
;""",conn)
# Out:
#    coin_id     avg_price  avg_stock_volume
# 0  bitcoin  8.893161e+06      4.854232e+09

# %% [markdown]
# # 22.Check if oil prices with S&P 500 high (correlation idea). 2025

# %%
pd.read_sql("""SELECT
avg(o.price_inr) as avg_oil,
avg(s.high) AS avg_stock_high
FROM top3_daily_price_1year_inr t
JOIN oil_prices o ON t.date = o.date
JOIN stock_prices s ON t.date = s.date
WHERE t.date BETWEEN '2025-01-01' AND '2025-12-31';
""",conn)
# Out:
#      avg_oil  avg_stock_high
# 0  64.413718    17135.990975

# %% [markdown]
# # 23.Find the average price and avgerage low stock price for 2025-2026.

# %%
pd.read_sql("""SELECT
avg(price_inr) as avg_price,
avg(s.low) AS avg_stock_low
FROM top3_daily_price_1year_inr t
JOIN stock_prices s ON t.date = s.date
WHERE t.date BETWEEN '2025-01-01' AND '2026-12-31';
""",conn)
# Out:
#       avg_price  avg_stock_low
# 0  3.053745e+06   17081.850665

# %% [markdown]
# # 24.compare the oil price and the average volume stock price between 2020 and 2025."

# %%
pd.read_sql("""SELECT
o.date AS oil_date,
avg(o.price_inr) as avg_price,
avg(s.volume) AS avg_stock_volume
FROM oil_prices o
JOIN stock_prices s ON o.date = s.date
WHERE s.date BETWEEN '2020-01-01' AND '2025-12-31';
""",conn)
# Out:
#      oil_date  avg_price  avg_stock_volume
# 0  2020-01-02  70.250736      3.448263e+09

# %% [markdown]
# # 25.Retrieve top3 historical prices and stock ticker, volume, and date for stock data between 2024 and 2025.

# %%
pd.read_sql("""SELECT
avg (price_inr) as price_inr,
s.ticker AS stock_ticker,
s.volume AS stock_volume
FROM top3_daily_price_1year_inr t
JOIN stock_prices s ON t.date = s.date
WHERE t.date BETWEEN '2024-01-01' AND '2025-12-31'
ORDER BY t.date;
""",conn)
# Out:
#       price_inr stock_ticker  stock_volume
# 0  3.059776e+06        ^NSEI        267000

# %% [markdown]
# # 26.Find the average close and oil price for the stock ticker 'NSEI' between 2020 and 2025.

# %%
pd.read_sql("""SELECT
 AVG(s.close) AS avg_stock_close,
 AVG(price_inr) AS avg_price
FROM oil_prices o
JOIN stock_prices s ON o.date = s.date
WHERE s.ticker = '^NSEI'
  AND o.date BETWEEN '2020-01-01' AND '2025-12-31';
""",conn)
# Out:
#    avg_stock_close  avg_price
# 0     18521.070923  70.211371

# %% [markdown]
# # 27.Compare the monthly average close prices of stock prices with oil prices.

# %%
pd.read_sql("""SELECT
oil_prices.date,  ticker,
strftime('%Y-%m', stock_prices.date) AS month,
AVG(close) AS avg_close
from oil_prices
join stock_prices on oil_prices.date=stock_prices.date
GROUP BY ticker, month
ORDER BY ticker, month;
""",conn)
# Out:
#            date ticker    month     avg_close
# 0    2020-01-02  ^GSPC  2020-01   3278.202858
# 1    2020-02-03  ^GSPC  2020-02   3277.314183
# 2    2020-03-02  ^GSPC  2020-03   2652.393632
# 3    2020-04-01  ^GSPC  2020-04   2761.975226
# 4    2020-05-01  ^GSPC  2020-05   2919.608484
# ..          ...    ...      ...           ...
# 214  2025-09-02  ^NSEI  2025-09  24957.799944
# 215  2025-10-01  ^NSEI  2025-10  25507.420215
# 216  2025-11-03  ^NSEI  2025-11  25887.726677
# 217  2025-12-01  ^NSEI  2025-12  25997.738725
# 218  2026-01-02  ^NSEI  2026-01  26076.408529
#
# [219 rows x 4 columns]

# %% [markdown]
# # 28.Find the top 5 stock tickers with the largest price difference between high and low on the same date

# %%
pd.read_sql("""SELECT
 ticker,
(high - low) AS price_diff
FROM top3_daily_price_1year_inr t
JOIN stock_prices s ON t.date = s.date
WHERE ticker = '^GSPC'
ORDER BY price_diff DESC
LIMIT 5;
""",conn)
# Out:
#   ticker  price_diff
# 0  ^GSPC  532.909668
# 1  ^GSPC  532.909668
# 2  ^GSPC  532.909668
# 3  ^GSPC  411.529785
# 4  ^GSPC  411.529785

# %% [markdown]
# #29.Find the top 2 tickers and close in stock prices.

# %%
pd.read_sql("""SELECT
 s.ticker AS stock_ticker,
 s.close AS stock_close
FROM stock_prices s
WHERE s.ticker IN ('^NSEI', '^GSPC')
 ORDER BY  s.ticker
 limit 10;
""",conn)
# Out:
#   stock_ticker  stock_close
# 0        ^GSPC  3257.850098
# 1        ^GSPC  3234.850098
# 2        ^GSPC  3246.280029
# 3        ^GSPC  3237.179932
# 4        ^GSPC  3253.050049
# 5        ^GSPC  3274.699951
# 6        ^GSPC  3265.350098
# 7        ^GSPC  3288.129883
# 8        ^GSPC  3283.149902
# 9        ^GSPC  3289.290039

# %% [markdown]
# # 30.Find the top 5 stock tickers with the highest price difference (calculated as high - low) for the ticker 'GSPC' (S&P 500) from the stock prices table.

# %%
pd.read_sql("""SELECT
 ticker,
(high - low) AS price_diff
FROM stock_prices s
WHERE ticker = '^GSPC'
ORDER BY price_diff DESC
LIMIT 5;
""",conn)
# Out:
#   ticker  price_diff
# 0  ^GSPC  532.909668
# 1  ^GSPC  411.529785
# 2  ^GSPC  357.050293
# 3  ^GSPC  237.879883
# 4  ^GSPC  236.300293

# %% [markdown]
# # Install streamlit

# %%
# !pip install -q streamlit
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
import subprocess
subprocess.Popen(["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"])
# !nohup /content/cloudflared-linux-amd64 tunnel --url http://localhost:8501 &
# Out:
# --2026-02-05 12:35:42--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.1.2/cloudflared-linux-amd64 [following]
# --2026-02-05 12:35:42--  https://github.com/cloudflare/cloudflared/releases/download/2026.1.2/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/31ade8d6-2fcd-4925-9218-5534d27a01dc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-05T13%3A33%3A35Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-05T12%3A32%3A41Z&ske=2026-02-05T13%3A33%3A35Z&sks=b&skv=2018-11-09&sig=vR4cIPmoDSB%2F88A1pDI3fwDkfHLihfTPLQOl6oL3kQM%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MDI5Njc0MiwibmJmIjoxNzcwMjk0OTQyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.nrGwUiqtcpxf_UcOsQNXxq-oytzdXV6-sqtRPAmgiC0&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2026-02-05 12:35:42--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/31ade8d6-2fcd-4925-9218-5534d27a01dc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-05T13%3A33%3A35Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-05T12%3A32%3A41Z&ske=2026-02-05T13%3A33%3A35Z&sks=b&skv=2018-11-09&sig=vR4cIPmoDSB%2F88A1pDI3fwDkfHLihfTPLQOl6oL3kQM%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MDI5Njc0MiwibmJmIjoxNzcwMjk0OTQyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.nrGwUiqtcpxf_UcOsQNXxq-oytzdXV6-sqtRPAmgiC0&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41260428 (39M) [application/octet-stream]
# Saving to: ‘cloudflared-linux-amd64.2’
#
# cloudflared-linux-a 100%[===================>]  39.35M   255MB/s    in 0.2s
#
# 2026-02-05 12:35:43 (255 MB/s) - ‘cloudflared-linux-amd64.2’ saved [41260428/41260428]
#
# nohup: appending output to 'nohup.out'

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Your tunnel url {}"
# Out:
# Your tunnel url https://moral-helped-walks-green.trycloudflare.com

# %%
# %%writefile app.py
import streamlit as st
import sqlite3
import pandas as pd
import datetime as dt

st.sidebar.title("Navigation")

menu = st.sidebar.selectbox(
    "Select a page:",
    ["Home", "Cross Market Overview", "SQL Query Runner", "Top 3 Crypto Analysis"]
)

# -------------------------
# HOME PAGE
# -------------------------
if menu == "Home":
    st.title("📊 Cross Market Analysis")
    st.write("Welcome to the Cross Market Analysis Dashboard")

# -------------------------
# CROSS MARKET OVERVIEW
# -------------------------
elif menu == "Cross Market Overview":
    st.title("📈 Cross Market Overview")

    conn = sqlite3.connect("Market.db")

    st.subheader("Select Date Range")
    start_date = st.date_input("Start Date", value=pd.to_datetime("2020-01-01"))
    end_date = st.date_input("End Date", value=pd.to_datetime("today"))

    btc_q = f"""
    SELECT date, current_price AS bitcoin_price
    FROM Cryptocurrencies
    WHERE date BETWEEN '{start_date.strftime('%Y-%m-%d')}' AND '{end_date.strftime('%Y-%m-%d')}'
    """

    oil_q = f"""
    SELECT date, price_inr AS oil_price
    FROM oil_prices
    WHERE date BETWEEN '{start_date.strftime('%Y-%m-%d')}' AND '{end_date.strftime('%Y-%m-%d')}'
    """

    sp_q = f"""
    SELECT date, close AS sp500_close
    FROM stock_prices
    WHERE ticker = '^GSPC'
      AND date BETWEEN '{start_date.strftime('%Y-%m-%d')}' AND '{end_date.strftime('%Y-%m-%d')}'
    """

    nifty_q = f"""
    SELECT date, close AS nifty_close
    FROM stock_prices
    WHERE ticker = '^NSEI'
      AND date BETWEEN '{start_date.strftime('%Y-%m-%d')}' AND '{end_date.strftime('%Y-%m-%d')}'
    """

    btc_df = pd.read_sql(btc_q, conn)
    oil_df = pd.read_sql(oil_q, conn)
    sp_df = pd.read_sql(sp_q, conn)
    nifty_df = pd.read_sql(nifty_q, conn)

    if not btc_df.empty and not oil_df.empty and not sp_df.empty and not nifty_df.empty:
        col1, col2, col3, col4 = st.columns(4)
        col1.metric("Bitcoin Avg", round(btc_df["bitcoin_price"].mean(), 2))
        col2.metric("Oil Avg", round(oil_df["oil_price"].mean(), 2))
        col3.metric("S&P 500 Avg", round(sp_df["sp500_close"].mean(), 2))
        col4.metric("NIFTY Avg", round(nifty_df["nifty_close"].mean(), 2))

        # -------------------------
        # 📅 Daily Market Snapshot (Separate Date Ranges)
        # -------------------------
        st.subheader("📅 Daily Market Snapshot (Separate Date Ranges)")

        # --- Bitcoin ---
        st.markdown("### 🪙 Bitcoin Date Range")
        btc_start = st.date_input("Bitcoin Start Date", dt.date(2026, 1, 29), key="btc_start")
        btc_end   = st.date_input("Bitcoin End Date", dt.date(2026, 2, 4), key="btc_end")

        btc_snap = pd.read_sql(f"""
        SELECT date, current_price AS bitcoin_price
        FROM Cryptocurrencies
        WHERE id = 'bitcoin'
          AND date BETWEEN '{btc_start}' AND '{btc_end}'
        ORDER BY date;
        """, conn)

        st.dataframe(btc_snap, use_container_width=True)

        # --- Oil ---
        st.markdown("### 🛢️ Oil Date Range")
        oil_start = st.date_input("Oil Start Date", dt.date(2020, 1, 2), key="oil_start")
        oil_end   = st.date_input("Oil End Date", dt.date(2026, 1, 26), key="oil_end")

        oil_snap = pd.read_sql(f"""
        SELECT date, price_inr AS oil_price
        FROM oil_prices
        WHERE date BETWEEN '{oil_start}' AND '{oil_end}'
        ORDER BY date;
        """, conn)

        st.dataframe(oil_snap, use_container_width=True)

        # --- NIFTY ---
        st.markdown("### 📈 NIFTY Date Range")
        nifty_start = st.date_input("NIFTY Start Date", dt.date(2020, 1, 1), key="nifty_start")
        nifty_end   = st.date_input("NIFTY End Date", dt.date(2026, 1, 9), key="nifty_end")

        nifty_snap = pd.read_sql(f"""
        SELECT date, open, high, low, close, volume
        FROM stock_prices
        WHERE ticker = '^NSEI'
          AND date BETWEEN '{nifty_start}' AND '{nifty_end}'
        ORDER BY date;
        """, conn)

        st.dataframe(nifty_snap, use_container_width=True)

    else:
        st.warning("No data available for selected date range.")
# -------------------------
# SQL QUERY RUNNER
# -------------------------
elif menu == "SQL Query Runner":
    st.title("🔎 SQL Query Runner")

    conn = sqlite3.connect("Market.db")

    queries = {
       "1. Find the top 3 cryptocurrencies by market cap":
        "SELECT name, market_cap FROM cryptocurrencies ORDER BY market_cap DESC LIMIT 3;",

    "2. List all coins where circulating supply exceeds 90% of total supply":
        "SELECT name, circulating_supply, total_supply FROM cryptocurrencies WHERE circulating_supply >= 0.9 * total_supply;",

    "3. Get coins that are within 10% of their all-time-high (ATH)":
        "SELECT name, current_price, ath FROM cryptocurrencies WHERE current_price >= 0.9 * ath;",

    "4. Find the average market cap rank of coins with volume above 1B":
        "SELECT AVG(market_cap_rank) AS avg_rank FROM cryptocurrencies WHERE total_volume > 1000000000;",

    "5. Get the most recently updated coin":
       "SELECT id,symbol,name,date FROM Cryptocurrencies ORDER BY date DESC LIMIT 1; ",

    "6.Find the highest daily price of Bitcoin in the last 365 days.":
    "SELECT coin_id, MAX(price_inr) AS highest_price_last_365_days FROM top3_daily_price_1year_inr WHERE coin_id = 'bitcoin' AND date >= DATE('now', '-365 day');",

    "7.Calculate the average daily price of Ethereum in the past 1 year.":
    "Select  avg(price_inr)as avg_price_last_365_days from top3_daily_price_1year_inr where coin_id = 'ethereum' and date >= DATE('now', '-366 day');",

    "8.Show the daily price trend of Bitcoin in January 2025.":
    "Select date,coin_id,price_inr  from top3_daily_price_1year_inr  where coin_id = 'bitcoin' and date between '2025-01-01' and '2025-12-31'   order by date;",

    "9.Find the coin with the highest average price over 1 year.":
     "Select coin_id, avg(price_inr)as avg_price from top3_daily_price_1year_inr group by coin_id order by avg_price desc limit 1;",

    "10.Get the % change in Bitcoin’s price between Sep 2024 and Sep 2025.":
    "SELECT ((MAX(price_inr) - MIN(price_inr)) / MIN(price_inr)) * 100 AS pct_change FROM top3_daily_price_1year_inr WHERE coin_id='bitcoin'AND date BETWEEN '2025-01-27' AND '2026-01-26';",

    "11.Find the highest oil price in the last 5 years.":
    "Select max(price_inr) as highest_price from oil_prices where date >= DATE('now', '-5 years');",
    "12.Get the average oil price per year.":
    " SELECT strftime('%Y', date) AS year, ROUND(AVG(price_inr), 2) AS avg_price FROM oil_prices GROUP BY year ORDER BY year;",

   " 13.Show oil prices during COVID crash (March–April 2020).":
    "SELECT date, price_inr FROM oil_prices WHERE date BETWEEN '2020-03-01' AND '2020-04-30' ORDER BY date;",

    "14.Find the lowest price of oil in the last 10 years.":
     "Select min(price_inr) as lowest_price from oil_prices where date >= DATE('now', '-10 years');",

    "15.Calculate the volatility of oil prices (max-min difference per year).":
    "SELECT strftime('%Y', date) AS year, MAX(price_inr) AS max_price, MIN(price_inr) AS min_price, ROUND(MAX(price_inr) - MIN(price_inr), 2) AS volatility FROM oil_prices GROUP BY year  ORDER BY year;",

    "16.Get all stock prices for a given ticker":
    "SELECT * FROM stock_prices GROUP BY ticker ORDER BY date;",

    "17.Find the highest closing price for NASDAQ (^IXIC)":
    "SELECT MAX(close) AS highest_close FROM stock_prices WHERE ticker = '^IXIC';",

    "18.List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)":
    "SELECT date, (high - low) AS price_diff FROM stock_prices WHERE ticker = '^GSPC' ORDER BY price_diff;",

    "19.Get monthly average closing price for each ticker":
    "SELECT ticker, strftime('%Y-%m', date) AS month, AVG(close) AS avg_close FROM stock_prices GROUP BY ticker, month ORDER BY ticker, month;",

    "20.Get average trading volume of NSEI in 2024":
    "SELECT AVG(volume) AS avg_volume_2024 FROM stock_prices WHERE ticker = '^NSEI' AND date BETWEEN '2024-01-01' AND '2024-12-31';",

    "21. Find the Average Bitcoin vs stock volume average price.":
    "Select  coin_id, avg(price_inr)as avg_price, avg(s.volume) AS avg_stock_volume from top3_daily_price_1year_inr t join stock_prices s on t.date = s.date where coin_id = 'bitcoin';",

    "22.Check if oil prices with S&P 500 high (correlation idea). 2025.":
    "SELECT avg(o.price_inr) as avg_oil, avg(s.high) AS avg_stock_high FROM top3_daily_price_1year_inr t JOIN oil_prices o ON t.date = o.date JOIN stock_prices s ON t.date = s.date WHERE t.date BETWEEN '2025-01-01' AND '2025-12-31';",

    "23.Find the average price and avgerage low stock price for 2025-2026.":
    "SELECT avg(price_inr) as avg_price, avg(s.low) AS avg_stock_low FROM top3_daily_price_1year_inr t JOIN stock_prices s ON t.date = s.date WHERE t.date BETWEEN '2025-01-01' AND '2026-12-31';",

    "24.compare the oil price and the average volume stock price between 2020 and 2025.":
    "SELECT o.date AS oil_date, avg(o.price_inr) as avg_price, avg(s.volume) AS avg_stock_volume FROM oil_prices o JOIN stock_prices s ON o.date = s.date WHERE s.date BETWEEN '2020-01-01' AND '2025-12-31';",

    "25.Retrieve top3 historical prices and stock ticker, volume, and date for stock data between 2024 and 2025.":
    "SELECT avg (price_inr) as price_inr, s.ticker AS stock_ticker, s.volume AS stock_volume FROM top3_daily_price_1year_inr t JOIN stock_prices s ON t.date = s.date WHERE t.date BETWEEN '2024-01-01' AND '2025-12-31' ORDER BY t.date;",

    "26.Find the average close and oil price for the stock ticker 'NSEI' between 2020 and 2025.":
    "SELECT AVG(s.close) AS avg_stock_close, AVG(price_inr) AS avg_price FROM oil_prices o JOIN stock_prices s ON o.date = s.date WHERE s.ticker = '^NSEI'   AND o.date BETWEEN '2020-01-01' AND '2025-12-31';",

    "27.Compare the monthly average close prices of stock prices with oil prices.":
    "SELECT oil_prices.date,  ticker, strftime('%Y-%m', stock_prices.date) AS month, AVG(close) AS avg_close from oil_prices join stock_prices on oil_prices.date=stock_prices.date GROUP BY ticker, month ORDER BY ticker, month;",

    "28.Find the top 5 stock tickers with the largest price difference between high and low on the same date":
    "SELECT ticker,(high - low) AS price_diff FROM top3_daily_price_1year_inr t JOIN stock_prices s ON t.date = s.date WHERE ticker = '^GSPC' ORDER BY price_diff DESC Limit 5;",

    "29.Find the top 2 tickers and close in stock prices.":
    "SELECT   s.ticker AS stock_ticker,  s.close AS stock_close FROM stock_prices s  WHERE s.ticker IN ('^NSEI', '^GSPC')  ORDER BY  s.ticker limit 10;",

    "30.Find the top 5 stock tickers with the highest price difference (calculated as high - low) for the ticker 'GSPC' (S&P 500) from the stock prices table.":
    "SELECT  ticker, (high - low) AS price_diff FROM stock_prices s WHERE ticker = '^GSPC' ORDER BY price_diff DESC LIMIT 5;"
    }

    selected_question = st.selectbox("Select a Question", list(queries.keys()))
    st.text_area("SQL Query", queries[selected_question], height=80)

    if st.button("Run Query"):
        try:
            df = pd.read_sql(queries[selected_question], conn)
            st.success("Query executed successfully!")
            st.dataframe(df)
        except Exception as e:
            st.error(f"Error: {e}")

# -------------------------
# TOP 3 CRYPTO ANALYSIS
# -------------------------
elif menu == "Top 3 Crypto Analysis":
    st.title("🪙 Top 3 Crypto Analysis")

    conn = sqlite3.connect("Market.db")

    coins = {
        "Bitcoin (BTC)": "bitcoin",
        "Ethereum (ETH)": "ethereum",
        "Tether (USDT)": "tether"
    }

    selected_coin_name = st.selectbox("Select a Coin", list(coins.keys()))
    selected_coin = coins[selected_coin_name]

    col1, col2 = st.columns(2)
    with col1:
        start_date = st.date_input("Start date", dt.date(2025, 2, 5))
    with col2:
        end_date = st.date_input("End date", dt.date(2026, 2, 4))

    if st.button("Show Price"):
        query = """
        SELECT DISTINCT date, price_inr
        FROM top3_daily_price_1year_inr
        WHERE coin_id = ?
          AND date BETWEEN ? AND ?
        ORDER BY date ASC
        """

        df = pd.read_sql(query, conn, params=(selected_coin, str(start_date), str(end_date)))

        if df.empty:
            st.warning("No data found for this period.")
        else:
            st.success(f"Daily price for {selected_coin_name}")
            st.dataframe(df)
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Your tunnel url {}"
# Out:
# Your tunnel url https://moral-helped-walks-green.trycloudflare.com
